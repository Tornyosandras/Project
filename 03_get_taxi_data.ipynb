# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
import requests

# %%
url = f"https://data.cityofchicago.org/resource/ajtu-isnz.json?trip_id=000001dd3888f74eaf131b0627d367e8c5b73cc4"
response = requests.get(url)
data = response.json()

# %%
current_datetime = datetime.now() - relativedelta(months=2)
formatted_datetime = current_datetime.strftime("%Y-%m-%d")
url = (
    f"https://data.cityofchicago.org/resource/ajtu-isnz.json?"
    f"$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' "
    f"AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"
)
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# [{'trip_id': '010300f389911c912364b2fe92bc2e9fc7ddd09b',
#   'taxi_id': '98bce2b72cd4ab0b4eff6a8e583554a5b42a4403647952a3e1824a20e29da3f61936ff9680f72989e55c7aeece0cfe8622c587a6c36ecd1b524a0cfa533c677e',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '24',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '3.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '3.25',
#   'payment_type': 'Cash',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'fd804b7f1465c47b4b3219acbe869e42adba1c73',
#   'taxi_id': 'f5eb0a822a607eab0ed4a970d1ccc3728a500fe45f7476cf4eeffadf4b8eab63af533fe1cf82d1bbd30f0c152b8b29086fe542aaa0ad14210b2a7a9f567b973d',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '801',
#   'trip_miles': '2.03',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '11.57',
#   'tips': '2.54',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '14.11',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'f67041df3d48d6cbb43d51594691f6ea1edd7aeb',
#   'taxi_id': '63d895bf335c522af83a8f2c608e31bb46a5d78cde4df21dbed059b4c61798625c7eb0591a46fd6224d257d5eae6519b621fb341a45510bced64a821f81b7fa6',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '755',
#   'trip_miles': '9.5',
#   'pickup_community_area': '11',
#   'dropoff_community_area': '76',
#   'fare': '25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '25',
#   'payment_type': 'Cash',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.978829526',
#   'pickup_centroid_longitude': '-87.771166703',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.771166703, 41.9788295262]},
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'f45550c48af51ec825c47513440fcbb178601266',
#   'taxi_id': '362dbe26e2730f8c392d5dc3e48fe2dfdebfa8e15dd52ffbc5ae278fcf6f9be46d7e6e7ab65257f757396285d56ff53193008182813465dbdf580aa24165e908',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '160',
#   'trip_miles': '0.77',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '5',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '14.5',
#   'payment_type': 'Credit Card',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.97907082',
#   'dropoff_centroid_longitude': '-87.903039661',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': 'f392dcd96e60bdda259511e196ced952bbd3ca6e',
#   'taxi_id': '35def117d7f62fb6cdb3752226cc2a4af2289a256011aad909eda7329af7be65db8eab83ad37d1922edfae781562d4cd9c5a0ea499c36ee735355f624df01812',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '974',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '16',
#   'fare': '1',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '1',
#   'payment_type': 'Cash',
#   'company': 'Tac - Yellow Cab Association',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.953582125',
#   'dropoff_centroid_longitude': '-87.72345239',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7234523905, 41.9535821253]}},
#  {'trip_id': 'e4f61327a5124e6ab083c5404206b74c1a33cbcf',
#   'taxi_id': 'd41e198fbed96bdbe8649a6c626cfeb16e5f82ca39a0c72bde5344a5166779475e0035d83523884b2e5d36ec55f91f94101f6e7c35bb3d056464c726614f1a81',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '871',
#   'trip_miles': '8.08',
#   'pickup_community_area': '76',
#   'fare': '21.75',
#   'tips': '5.25',
#   'tolls': '0.01',
#   'extras': '4',
#   'trip_total': '31.51',
#   'payment_type': 'Credit Card',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'e209efc5fcf8d036244258300b825d2c504fa04c',
#   'taxi_id': '950af3418bda33a809615e29c0592a6ab8ed5f479173437b80b129e16694d099c13ac649b93c38a08e703f3bc8c11a16bf7c37ccca96824dd06c56709d6afeac',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '1167',
#   'trip_miles': '11.57',
#   'pickup_community_area': '12',
#   'dropoff_community_area': '32',
#   'fare': '30.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30.25',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.993930128',
#   'pickup_centroid_longitude': '-87.758353588',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7583535876, 41.9939301285]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'd923435fd9b1a5eb332fef1896a827a2a5eead8f',
#   'taxi_id': 'f35fcc7d28fd3ca0324ad6b42c6bf1dd0413320a9c4b65cb10b92def1ea763bd2bd706f4e189be46b08d37e56f1ddb72f06d89e6a64e0cb7172e3618e519c33e',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1559',
#   'trip_miles': '13.88',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '6',
#   'fare': '36',
#   'tips': '8.1',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '48.6',
#   'payment_type': 'Credit Card',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': 'd9155081197292341ca5f2e3fdb268cafa6228e8',
#   'taxi_id': 'd3b33673ee1a39325983e66d426003caf668f4509230cb06acb1138c0301b49ba4864d9f4257f37160454b20d3be0046781e9c96d10dfe095ae59e170d9cce84',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1800',
#   'trip_miles': '10.8',
#   'pickup_community_area': '41',
#   'dropoff_community_area': '43',
#   'fare': '29.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '29.5',
#   'payment_type': 'Unknown',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.794090253',
#   'pickup_centroid_longitude': '-87.592310855',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.592310855, 41.794090253]},
#   'dropoff_centroid_latitude': '41.761577908',
#   'dropoff_centroid_longitude': '-87.572781987',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5727819867, 41.7615779081]}},
#  {'trip_id': 'd54b9566ddec7a030c1d96bdef1dd6b4cf92e665',
#   'taxi_id': '85c39e068db414d181c6252a89fd822afc2e169a9a9e853a14000c4e8d301ab4158f92ddb7d420aad7b979d438b7b61b5bd888bc8803a0050af936b7f6c3e370',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '659',
#   'trip_miles': '2.54',
#   'pickup_community_area': '7',
#   'dropoff_community_area': '8',
#   'fare': '12.34',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12.34',
#   'payment_type': 'Mobile',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.922686284',
#   'pickup_centroid_longitude': '-87.649488729',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'd3170c2124a209ae7066cb0ae1b85761ab67a259',
#   'taxi_id': '9f03af7a7243ab995b3b0c11480a44dd1d62ee389899b966b19fd23686687ff3a49e299d548aadc769cb91d0495a831de0ab0668ad94d86b065404d946affde7',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1560',
#   'trip_miles': '14.3',
#   'fare': '36.75',
#   'tips': '10.3',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '51.05',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency, LLC'},
#  {'trip_id': 'd0e9d4007e00c22a7328b289eeaab125425d55ad',
#   'taxi_id': '04c44d1bf8cc741f86f8ccdee5b64b65e5a6631d743450a231aa5efbd6f3cde831cf7b983a65bd9b22563c53f4f0deca843c689ba3db19124a48e6fb05f23b61',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '985',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '6',
#   'fare': '21.61',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '21.61',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': 'cf2f28e7dafb85291d387b584d5dffa43aab20bd',
#   'taxi_id': '08d898cd310449bd541a95eedd05a139ad1176e66c06c3f256333b47868822544424b1c654f7c9712d2febf0209ace5a7315c61f2ea63d3bc9eab489383fd9bc',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1277',
#   'trip_miles': '10.08',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '1',
#   'fare': '26.16',
#   'tips': '6.87',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '33.03',
#   'payment_type': 'Mobile',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '42.009622881',
#   'dropoff_centroid_longitude': '-87.670166857',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6701668569, 42.0096228806]}},
#  {'trip_id': 'c9d9fd0d91661eb9ea5ed78a487435306eccd598',
#   'taxi_id': '561fbb8af15689fe33fb11b96905cfb95d11ac44700c1a476e474b9b19d4dc24fec8cbfe3df913dc2ee78f919bd0b1cb416be0bc3b0a431d4335bfae2df63278',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '172',
#   'trip_miles': '0.27',
#   'pickup_census_tract': '17031081600',
#   'dropoff_census_tract': '17031081600',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '4.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '4.25',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.892072635',
#   'pickup_centroid_longitude': '-87.628874157',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6288741572, 41.8920726347]},
#   'dropoff_centroid_latitude': '41.892072635',
#   'dropoff_centroid_longitude': '-87.628874157',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6288741572, 41.8920726347]}},
#  {'trip_id': 'c9a5d49cfb023f69e49304aeadba13215ac0b87f',
#   'taxi_id': '791d74df896226a452a8e223e2ec9fa0df7d80bb7ca1803a962825ee533a7efeda3d8c70a664fac35aa72b8ac4766174a796ff100f1b084081dd20b07a412e46',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1560',
#   'trip_miles': '12',
#   'pickup_community_area': '15',
#   'dropoff_community_area': '32',
#   'fare': '32.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '32.75',
#   'payment_type': 'Unknown',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.954027649',
#   'pickup_centroid_longitude': '-87.763399032',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7633990316, 41.9540276487]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'c6218dd6a4e2014665ac58acd5e2b241d545bf89',
#   'taxi_id': '38e76b98810925c37414db66db5639e5ddf49c0dbda887da38c63d1335ad66ecd8a566c34553dddcf17fdac0c893f8768449bedf93d94b46ed8d9238fa6a4ea7',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '900',
#   'trip_miles': '3',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '24',
#   'fare': '11.5',
#   'tips': '2.4',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '13.9',
#   'payment_type': 'Credit Card',
#   'company': '3591 - 63480 Chuks Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': 'c30f403017893dfaab160d37e5fbed1cfb7765d7',
#   'taxi_id': 'c4b8125a4c89c864b1f5dfc240ff17752f46dc27f574cf74639fa5fef58cceca766fa2e9b2ec2ccb2e3c8491ffef827e3531bccef703d5fa2908a726e1f093cf',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1800',
#   'trip_miles': '14.3',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '6',
#   'fare': '37',
#   'tips': '8.3',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '49.3',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': 'bf7b6d2befba166479b559c7473979a885381ee4',
#   'taxi_id': '081758ced4767105bfa217f7b0784d72d37e12a016fe2afe00706141bef5950c435d6dc7b112c594bcf48f00f40817f995f9f4ac20a91a9c01b6c11accf0d9ff',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '475',
#   'trip_miles': '1.31',
#   'pickup_census_tract': '17031833000',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '10',
#   'tips': '2.12',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12.12',
#   'payment_type': 'Mobile',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.88528132',
#   'pickup_centroid_longitude': '-87.6572332',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': 'bca537adaa3c7349c3668c113a251f5a0ad316e2',
#   'taxi_id': 'cd055d663816c614ef9fc2611bd1f8029da29eeaac7070f641eb20da85faa061b17c7a473ddc164518725ae0cbdded29034237e17faa0d063cd62bceab7a32b1',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1387',
#   'trip_miles': '14.92',
#   'pickup_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'fare': '37.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '23',
#   'trip_total': '60.5',
#   'payment_type': 'Cash',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': 'b80feb07c2f33ad06a3e338aec29ff07ed9a69cf',
#   'taxi_id': 'f760c301740afe577d6c0e2f6de2cfecccf6ede158b8a3825331005da37a008716599169f4b467bc8b88e65318b5008499ad0ea4e05a7465c6bce4a1d5e70350',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:45:00.000',
#   'trip_seconds': '2735',
#   'trip_miles': '9.58',
#   'pickup_community_area': '2',
#   'dropoff_community_area': '32',
#   'fare': '29.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '29.25',
#   'payment_type': 'Prcard',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '42.001571027',
#   'pickup_centroid_longitude': '-87.695012589',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6950125892, 42.001571027]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'b61e165a7d48707e57b28078d32bede381a6bee8',
#   'taxi_id': 'c531f081cad817a366cbae2254ce7a3bb370394b3b0f1399dfc8781333c3565ca188035bbff4d1d7652181b79712c103d01ab168cb6ca2580f2da4b324cb00a5',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '789',
#   'trip_miles': '2.36',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '10.39',
#   'tips': '3.07',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '13.46',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'b40a82031c3db588ac90119a560e11fa870264be',
#   'taxi_id': '509476ab6ed3f69bed54dcde037df74912a813e77d8fd8223c0325bbb94e911fd2132d798c98139b27f9ab2bc2a27304cb242d37ea10f79eb02396efc31c7294',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1796',
#   'trip_miles': '13.83',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '1',
#   'fare': '35.75',
#   'tips': '10',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '50.25',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '42.009622881',
#   'dropoff_centroid_longitude': '-87.670166857',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6701668569, 42.0096228806]}},
#  {'trip_id': 'ad21c559402b69a6c7890042ddbbfd7221aff27e',
#   'taxi_id': '3497d2b935bf09123c257fd1ff03b4ca266e067fac8e97007b30bd3e5138ca4988760b37ee60b57ccf32fd220729611e04a99d769bcd0d06c5d64911df2f1da1',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '1140',
#   'trip_miles': '16.5',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '40.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '45.5',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'acb035600a78e8e7542c5d0ae3d1cfb81d96edec',
#   'taxi_id': '3618045f9110d4d88482266ade23659c1a50d32ac37f205c15614b1ada9d4ca14b171329afed5dfd81c7525bd5a05fe614cb63b2aa48d920626b519e20d9e146',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '1080',
#   'trip_miles': '4.7',
#   'pickup_community_area': '22',
#   'dropoff_community_area': '8',
#   'fare': '15',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '15',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.92276062',
#   'pickup_centroid_longitude': '-87.699155343',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'a8e6ff341ee6409f47f5116523290779de7000aa',
#   'taxi_id': '342474dd3a24c9d5b7dbc2514032a01ecb396624638be510614948e1bfbcaff802b12a713e58742d8597899edbcf1c4926ae2238b9612b4f8c10faad33621650',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '840',
#   'trip_miles': '1.2',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '8',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '3',
#   'trip_total': '11',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'a75dc92e80a16c6b0aa1c40a1b6198b8277f169e',
#   'taxi_id': 'ef32ded438e4b619ee3c0764226668e39c11075dafc385a8201a866c12440cf5025d3b754141dccf276ce01994202ec9f2c160af14743a7d33258aa78e93cd76',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '307',
#   'trip_miles': '1.08',
#   'pickup_census_tract': '17031081500',
#   'dropoff_census_tract': '17031080202',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '6',
#   'tips': '3',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '10.5',
#   'payment_type': 'Credit Card',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.892507781',
#   'pickup_centroid_longitude': '-87.626214906',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]},
#   'dropoff_centroid_latitude': '41.905857769',
#   'dropoff_centroid_longitude': '-87.630865027',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6308650266, 41.9058577688]}},
#  {'trip_id': '9da4515dd7d35c2ee73630387801509cbcfd6b8c',
#   'taxi_id': '9475d35df519612aec86dbbfcb872633159f538fe7d90aea0c11732d3d6674dfcbe6758dca70f9125b5add9c895dd2a996bbe3dc2a1dd6165b047f790998fddd',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1464',
#   'trip_miles': '11.97',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '16',
#   'fare': '34.86',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '34.86',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.953582125',
#   'dropoff_centroid_longitude': '-87.72345239',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7234523905, 41.9535821253]}},
#  {'trip_id': '9d51f045f0858298fcc2ad7f6c47dfa6039ed413',
#   'taxi_id': '488f74778b200fa256453e785aceb902249139d4880bc1779e356c06b38f3c5e7a8a77ad920f3a40883aaaa81baa970cfe70c83c7b11d0344836f9b32b134822',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1800',
#   'trip_miles': '12.44',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '25',
#   'fare': '32.25',
#   'tips': '4',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '41.75',
#   'payment_type': 'Credit Card',
#   'company': 'Chicago Taxicab',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.890608853',
#   'dropoff_centroid_longitude': '-87.756046711',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7560467111, 41.8906088526]}},
#  {'trip_id': '96b299b1b003222bf67319ed1d9e6f1fa9001899',
#   'taxi_id': '3f68542d52a06c2f726a08b3888acb6e7979a3ade1b74c38c2d8d3932377185103d527e0a018b407d71e80217caa2a9335c74cc0dabf9f13141cf5875ef051b0',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '180',
#   'trip_miles': '0.4',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '4.5',
#   'tips': '4',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '8.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '8fa313f8f281d2e4fb05ec7d592efc970d0d9805',
#   'taxi_id': 'a432fe577b3d7f89c3f91153dab9b75e527e63809a82a3a96388ec67c16f4150e361ee3e251ee9451cf3525f91dac89904deb7dc608349993fdb4ad62ba9a210',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '1283',
#   'trip_miles': '1.33',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '11',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '3',
#   'trip_total': '14',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '8b6797e2fba44e233e73e961d64faee97dff4b65',
#   'taxi_id': '89ef36585d68603f58ba7a6f23998ad78fd67f1a9a9ea4f38f06167114ca6d1b1b532e0f0ca38315d09542504b488d13865e6c372900a1c3ccf4acc044376134',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '616',
#   'trip_miles': '0.5',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '7.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '11.25',
#   'payment_type': 'Cash',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.97907082',
#   'dropoff_centroid_longitude': '-87.903039661',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': '89da0e9b8c66d09955d5e84b1bd216322c45e71c',
#   'taxi_id': '19a89fbfe54b0564c6961e347f5faa1158413d94d42ac5f92d09417a75c4362f684b96c26fa660d1171cd110800d2b4e7c059ac469868867dd4ddda0844a8672',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '6',
#   'trip_miles': '0',
#   'pickup_community_area': '7',
#   'dropoff_community_area': '7',
#   'fare': '30',
#   'tips': '7.62',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '38.12',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.922686284',
#   'pickup_centroid_longitude': '-87.649488729',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '8967ebf0d19039a8ce602cf341e1f3419468ec3f',
#   'taxi_id': '0b0be23bf69b80dd81715f86c4e0887bbd5d9ebc2463b88635ed2705c937720337de44f180656cbaead91809f85a2cb38eeb8370298563b0685d385a8eff8af6',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '716',
#   'trip_miles': '1.52',
#   'pickup_census_tract': '17031081600',
#   'dropoff_census_tract': '17031833000',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '28',
#   'fare': '8.25',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '1.5',
#   'trip_total': '12.25',
#   'payment_type': 'Credit Card',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.892072635',
#   'pickup_centroid_longitude': '-87.628874157',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6288741572, 41.8920726347]},
#   'dropoff_centroid_latitude': '41.88528132',
#   'dropoff_centroid_longitude': '-87.6572332',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]}},
#  {'trip_id': '890cfb89d7fbbc06bad14a755804e3337a170be9',
#   'taxi_id': '158bdb99c0944908e89681ab608203e360f6e359ad4d94ec66617bb6bbb09f1ba7472a0a7d43a8ef444c7218eba2ee8fe5ddab92691f52663915dabe84a03236',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '422',
#   'trip_miles': '1.43',
#   'pickup_community_area': '6',
#   'dropoff_community_area': '7',
#   'fare': '10',
#   'tips': '1',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.944226601',
#   'pickup_centroid_longitude': '-87.655998182',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '87b796310af8ae49d9b28321591703aab90c64d3',
#   'taxi_id': '2f8c51760f8358b29119959a9a4864d3d320e18a642b598248ccab958908a1da90ed708a7665d4a22a6c0c986b048239e4cd8fcff79c744d5ea2713259678b6a',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '795',
#   'trip_miles': '3.54',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '7',
#   'fare': '12.5',
#   'tips': '1.95',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '14.95',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '859d5d9c1434763d3fe75a53b9a21a527f9919b9',
#   'taxi_id': '15ebaceb1f5e522414ecc2fb3af8775a525ccbb8427e69e5d58364f166a9f2bb11ad29b537e2363c505dec29d069e10ea10d6e836077ce25883c5d8fa0dad189',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '592',
#   'trip_miles': '1.84',
#   'pickup_census_tract': '17031833000',
#   'dropoff_census_tract': '17031081100',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '8.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1.5',
#   'trip_total': '10',
#   'payment_type': 'Cash',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.88528132',
#   'pickup_centroid_longitude': '-87.6572332',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]},
#   'dropoff_centroid_latitude': '41.900221297',
#   'dropoff_centroid_longitude': '-87.629105186',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6291051864, 41.9002212967]}},
#  {'trip_id': '85663aa6a141b1f476b6cca43bffceab2eb67967',
#   'taxi_id': 'c4b8125a4c89c864b1f5dfc240ff17752f46dc27f574cf74639fa5fef58cceca766fa2e9b2ec2ccb2e3c8491ffef827e3531bccef703d5fa2908a726e1f093cf',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '1083',
#   'trip_miles': '4',
#   'pickup_community_area': '7',
#   'dropoff_community_area': '32',
#   'fare': '15.57',
#   'tips': '4.16',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '19.73',
#   'payment_type': 'Mobile',
#   'company': 'Tac - Yellow Cab Association',
#   'pickup_centroid_latitude': '41.922686284',
#   'pickup_centroid_longitude': '-87.649488729',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '830f71ea6aad424ce2fbabd53055a1a91954c015',
#   'taxi_id': '4001d6fc76fe3a71893de1de252a2dc07252f72e7869580755891b07b9725dda84847dbb0cd96eba5d66194f6fa232c7de105592c5e13e107dc32ced89edd1b4',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '587',
#   'trip_miles': '0',
#   'dropoff_community_area': '76',
#   'fare': '6.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '6.25',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '8235968d72df12946bc59eec00a7d01a4b08cdd8',
#   'taxi_id': '54ab53ea65bdfb30a1d764d23fa4f40261b6d8a657125abb18bb2d51deb130f318cf86d6595dd4fda9ce4ddbdfffe93384bb37326ff39d3a78da8a382a4b4d81',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '135',
#   'trip_miles': '0.37',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '22',
#   'fare': '4',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '5',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': '7bba0cf9810ad7c0c218b2a242f14310409f91ea',
#   'taxi_id': '8839ccb8023576f003704715e1e1b65c6fb03c6d86d9baa33f50f1d4e985223a290bb7e3849c645e62e31b3dfe88aed330b8f9a475a76709729fed427b07c514',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '198',
#   'trip_miles': '0.63',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '24',
#   'fare': '10',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12',
#   'payment_type': 'Mobile',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '7b64848ebb95995c3abb86a13a842dd615a522e4',
#   'taxi_id': '27f4e362035594e6144066180cd9f740961885b33231bd0ae10edcf14dd67f25d8298a6ac58216b2859f4bca45e236014b22b70bf771c92c3709ec80ad5b1f8b',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1036',
#   'trip_miles': '10.58',
#   'pickup_community_area': '27',
#   'dropoff_community_area': '68',
#   'fare': '27.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '28.5',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878914496',
#   'pickup_centroid_longitude': '-87.70589713',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7058971305, 41.8789144956]},
#   'dropoff_centroid_latitude': '41.777196255',
#   'dropoff_centroid_longitude': '-87.642497527',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6424975271, 41.7771962546]}},
#  {'trip_id': '77051763435782dfbd6687418671c2fa041cbeed',
#   'taxi_id': 'bb90b2306d04496af0bd28b855103080054c6c38bbbe8ed705601f5f429e090419071cfa08845ce6c7d97f0a14b3c1ae76db8b550ac40cb43f01ac2e44a1cb89',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '855',
#   'trip_miles': '2.81',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '7',
#   'fare': '10.75',
#   'tips': '4',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '15.25',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '6d8af2949ec06f69e67857f6ee6985aa4b99e963',
#   'taxi_id': '6fa0364cac8d604e8a7613c08fdcbe5bfa05e361d4a7585de8caaa7b5f12b0c5b3c3a00fe5e1bfe58c3341d7aa3e0c4ff23cbdf4375dd3e55f20b643e85ab683',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '1132',
#   'trip_miles': '12.1',
#   'pickup_community_area': '8',
#   'fare': '31.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '31.25',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '63ed646c3ffb2c51a2053f0df89207754f5f4ef9',
#   'taxi_id': 'b4918e3dc616260ba3c7c57ccf5345c43f853abd067d61aaa32e4ec344d44938260d4f7ef46913aa2a3ff556b05c32e3157899097fd68b8f732d88e3dd16d8dd',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '0',
#   'trip_miles': '0',
#   'fare': '0',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '0',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services'},
#  {'trip_id': '611535971a05ee31c57bb1cbaf3799e316779c3b',
#   'taxi_id': '6dbac74c2838addb28d0bf34cf126cf1624cc61180bfb2f89753e3502a23830135b61ebb9ce5902c21cc58a8587ca4f9a369cba30ca46a136813508f1e3cc4c7',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '1160',
#   'trip_miles': '6.27',
#   'pickup_community_area': '76',
#   'fare': '19',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '9.5',
#   'trip_total': '28.5',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '605859e1723488424e1632f2cd84d71fcfe86da2',
#   'taxi_id': 'b5d74b92d646ed1edaff1b165977d2a4a5d068792024841ddfbe2053ac5e0484c87043887dd4ce6295814d2a362907b5ccd06d64070eb7bb20111343bd4aad1d',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '111',
#   'trip_miles': '0.37',
#   'pickup_census_tract': '17031833000',
#   'dropoff_census_tract': '17031833000',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '28',
#   'fare': '4.99',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '4.99',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.88528132',
#   'pickup_centroid_longitude': '-87.6572332',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]},
#   'dropoff_centroid_latitude': '41.88528132',
#   'dropoff_centroid_longitude': '-87.6572332',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]}},
#  {'trip_id': '5dc0d26c39ee0c6ae464c880a86f2ecd3ceac867',
#   'taxi_id': '6adb02556453c79096b14273579cbc9db7df43dd51e443d7c851eb1b44409f91014edba53645d741741efdf5c56f8f615fdabaca50d0d5b64300c87cc80ce144',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:30:00.000',
#   'trip_seconds': '2260',
#   'trip_miles': '10.09',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '10',
#   'fare': '32.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '36.5',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.985015101',
#   'dropoff_centroid_longitude': '-87.804532006',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.8045320063, 41.9850151008]}},
#  {'trip_id': '5651abafd2379001db20c05947f32fbffc4d9ca6',
#   'taxi_id': 'b5d74b92d646ed1edaff1b165977d2a4a5d068792024841ddfbe2053ac5e0484c87043887dd4ce6295814d2a362907b5ccd06d64070eb7bb20111343bd4aad1d',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-11T23:45:00.000',
#   'trip_seconds': '278',
#   'trip_miles': '0.78',
#   'pickup_census_tract': '17031833000',
#   'dropoff_census_tract': '17031833000',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '28',
#   'fare': '5.25',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '8.75',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.88528132',
#   'pickup_centroid_longitude': '-87.6572332',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]},
#   'dropoff_centroid_latitude': '41.88528132',
#   'dropoff_centroid_longitude': '-87.6572332',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]}},
#  {'trip_id': '50accdb3125fa4f92734fa8a74f573ebc61e604d',
#   'taxi_id': 'ab31561a5548b1d49b0352bb8d00d18c0e136d5f674c1cb6f88a4381edd74510a2a3e3f47f56f8086b9712109368c294beef849a9ccf16792be72750a255544b',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '877',
#   'trip_miles': '2.22',
#   'pickup_census_tract': '17031833000',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '10.25',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '13.75',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.88528132',
#   'pickup_centroid_longitude': '-87.6572332',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': '4f03340cdae876d548c087a460de56a423ba9f7a',
#   'taxi_id': 'c34d6347f812df0e22ee1a907881bffff574dab3839a95c5bb06b084981ae17bc9bbcf5b534862cd5784e7b6ab5c990da8d61cdfbe5334edfa1b82d247a87db3',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:00:00.000',
#   'trip_seconds': '897',
#   'trip_miles': '0',
#   'pickup_community_area': '69',
#   'dropoff_community_area': '41',
#   'fare': '15',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '15',
#   'payment_type': 'Cash',
#   'company': 'Tac - Yellow Cab Association',
#   'pickup_centroid_latitude': '41.763246799',
#   'pickup_centroid_longitude': '-87.616134111',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6161341112, 41.7632467988]},
#   'dropoff_centroid_latitude': '41.794090253',
#   'dropoff_centroid_longitude': '-87.592310855',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.592310855, 41.794090253]}},
#  {'trip_id': '4c1797e5c08dd15681ec2aa55f2b05d90fce5d14',
#   'taxi_id': '9980554f20602531547b95999bd62f0e1c60ac5213e7fb410182a26dcf578cd2e57f4eabaa67c6a7588e7075af6416caae54bf200cc144e894cf656612f2d129',
#   'trip_start_timestamp': '2025-01-11T23:45:00.000',
#   'trip_end_timestamp': '2025-01-12T00:15:00.000',
#   'trip_seconds': '1731',
#   'trip_miles': '8.87',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '26.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '31.5',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
# ...
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:00:00.000',
#   'trip_seconds': '6',
#   'trip_miles': '0',
#   'pickup_community_area': '77',
#   'dropoff_community_area': '77',
#   'fare': '30',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30',
#   'payment_type': 'Cash',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.9867118',
#   'pickup_centroid_longitude': '-87.663416405',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6634164054, 41.9867117999]},
#   'dropoff_centroid_latitude': '41.9867118',
#   'dropoff_centroid_longitude': '-87.663416405',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6634164054, 41.9867117999]}},
#  {'trip_id': '7faf9b729d62c33e3f11e1f7bddc1afec2880bdb',
#   'taxi_id': 'e571c5fe8182d6ded4596be528c55bd4a011b726635dcf3180bd83b5b1928a9c47104440ab2d4ce9ca9e5525a9aeea126388728654cb09d2d0531235a9b5e6ca',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:00:00.000',
#   'trip_seconds': '2',
#   'trip_miles': '0',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '24',
#   'fare': '30',
#   'tips': '6.1',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '36.6',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '7f8ffac5665d75db57f973de2ece9140bb33e05a',
#   'taxi_id': '2ff2aaf64117e6b941f9cac81d550a4fe4fbd62cff03ffe79da3c15c64fac4da316aa0b66f153a7cca04e5cbe036a1ad4e843112a488c8facb631cb17e0b8fad',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:15:00.000',
#   'trip_seconds': '960',
#   'trip_miles': '10.9',
#   'pickup_community_area': '33',
#   'fare': '28.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '28.25',
#   'payment_type': 'Unknown',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.857183858',
#   'pickup_centroid_longitude': '-87.620334624',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6203346241, 41.8571838585]}},
#  {'trip_id': '7e5964ea4c96267eb0c94492ce2182e45919e9a2',
#   'taxi_id': 'f8c3f707897df1cb42ad97406a34c0047b077c9a1105d34e1b5a0ceba7575f97403536a1bdfebf30af132cd2d0ab3ff79f42545bd3ea4db4f3fa9aa0dc2d0ad4',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:30:00.000',
#   'trip_seconds': '1421',
#   'trip_miles': '13.44',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '41',
#   'fare': '34.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '39',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.794090253',
#   'dropoff_centroid_longitude': '-87.592310855',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.592310855, 41.794090253]}},
#  {'trip_id': '7d2f597956d03ba818eadf0a47c85b9b88d8eac4',
#   'taxi_id': '4c44c95be8b37539aff5ca9e7840cd7951ebf1fa73d62ed3d6b10ec6d2d989ea511d9093cbb739d708c85294f87e9ee27112d5b717c0685fab080f43458a38f4',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:15:00.000',
#   'trip_seconds': '1387',
#   'trip_miles': '13.27',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '6',
#   'fare': '32.75',
#   'tips': '7.45',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '44.7',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '7d0e395d569499b43848679650099b4547295456',
#   'taxi_id': 'd96ae448797afb997073c20b6bec963b3d693a3683dfb0e7894a5ac3de50e17cb15bb2a5c5c7860a5ced37de4a8df5cff14b317055309d6a5752f5520f739918',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:15:00.000',
#   'trip_seconds': '1014',
#   'trip_miles': '0',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '9.33',
#   'tips': '1.22',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '10.55',
#   'payment_type': 'Mobile',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '78b5e4b51bdd73db386da3aed4d65ecfff45acbe',
#   'taxi_id': '4b73d19af7e1fe6e8ad6b095cf52b354b0b5fad0edca75d686e3a87eb7f4dccb546d1ffb196e1252fa8481af1103c21041b2690a403c5f12c44d8b2961684885',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:30:00.000',
#   'trip_seconds': '1277',
#   'trip_miles': '8.02',
#   'dropoff_community_area': '11',
#   'fare': '23.37',
#   'tips': '6.4',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '29.77',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'dropoff_centroid_latitude': '41.978829526',
#   'dropoff_centroid_longitude': '-87.771166703',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.771166703, 41.9788295262]}},
#  {'trip_id': '78a2ae1c7875a6bdea461ed3a22d174011368a7b',
#   'taxi_id': '00f4b381570486f8575cbaa57ed41f116ed2e1f9d85f73bb2f6dba13a72541761d2ad4cb1727990d97795a2b0bdd99f0e4a8826245c81dac443cebb1c19b26fb',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:30:00.000',
#   'trip_seconds': '1140',
#   'trip_miles': '14.2',
#   'pickup_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'fare': '36',
#   'tips': '6.5',
#   'tolls': '0',
#   'extras': '25',
#   'trip_total': '67.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': '77a2a54088b042fd6a760e9af046dbb2c1463438',
#   'taxi_id': '693d50a88a25eeb78492f4619f5a6ecdde75f947ed8cc04d371c44baf3c2c86e90202bf88d14bfad9f82df4703e747dfd66e7cddf07208a5e24fc96e8a75239f',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:00:00.000',
#   'trip_seconds': '2',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '1',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '1',
#   'payment_type': 'Cash',
#   'company': 'Tac - Yellow Cab Association',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '75eb260eda578291da99d35dd55b173952684c09',
#   'taxi_id': '9757aea9fe516d22d0ddd0e77f1cb8a54a3e5f2b91e09785cf640d3429f50b3a6e5b2f6e46ceb49cabdcb36dc59deca4bd3a8a5dd01857b0da6f29035c902e59',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:45:00.000',
#   'trip_seconds': '2896',
#   'trip_miles': '24.6',
#   'pickup_community_area': '53',
#   'dropoff_community_area': '25',
#   'fare': '57.53',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '57.53',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.673819904',
#   'pickup_centroid_longitude': '-87.635739777',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6357397768, 41.6738199043]},
#   'dropoff_centroid_latitude': '41.890608853',
#   'dropoff_centroid_longitude': '-87.756046711',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7560467111, 41.8906088526]}},
#  {'trip_id': '71c765e7cb9304fe23145aa72b4888149ec23058',
#   'taxi_id': '55216d2322a853d318e183c048906299da0cfbc59dd4df60d175a82b7680d09696d638c10823fbece1daba767379f85e30ebef2c501739a404860ee654209808',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:45:00.000',
#   'trip_seconds': '2783',
#   'trip_miles': '0',
#   'pickup_community_area': '77',
#   'dropoff_community_area': '77',
#   'fare': '3.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '3.25',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.9867118',
#   'pickup_centroid_longitude': '-87.663416405',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6634164054, 41.9867117999]},
#   'dropoff_centroid_latitude': '41.9867118',
#   'dropoff_centroid_longitude': '-87.663416405',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6634164054, 41.9867117999]}},
#  {'trip_id': '70715240dc8e2f5c7e6033de8f2949769bcc1b55',
#   'taxi_id': '3f2bfdbb4c8687efc1618f15effbc93f8f04b12d712e38eb50122901937e5564ba654f42b7808a0f6b8ac0ac22de43db0ad4b192bc40d88c096050042667d8d3',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:15:00.000',
#   'trip_seconds': '790',
#   'trip_miles': '3.2',
#   'pickup_census_tract': '17031081300',
#   'dropoff_census_tract': '17031280100',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '28',
#   'fare': '11.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.75',
#   'payment_type': 'Cash',
#   'company': 'Choice Taxi Association Inc',
#   'pickup_centroid_latitude': '41.898331794',
#   'pickup_centroid_longitude': '-87.620762865',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6207628651, 41.8983317935]},
#   'dropoff_centroid_latitude': '41.885300022',
#   'dropoff_centroid_longitude': '-87.642808466',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6428084655, 41.8853000224]}},
#  {'trip_id': '6908374835b7416a36f0e20c3f296ef061a4b9e7',
#   'taxi_id': '1eba7c19fc49260d67105f0fa98a4be0f4aa006f4d3959de6fc044c3fb9039f9a02c7e21005260a9c3fecb1276cb38839abb8c544759ccf7a9af08f7df0e7e0e',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:00:00.000',
#   'trip_seconds': '404',
#   'trip_miles': '0',
#   'dropoff_community_area': '6',
#   'fare': '4',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '4',
#   'payment_type': 'Cash',
#   'company': 'Tac - Yellow Cab Association',
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '680fe4538fa936af1b6d4a506000050e448bd9ce',
#   'taxi_id': '698ec513d27602fcd211bb62440a555a3f23bebbe3b2a1ec9ba6466a63bab46628c6dc1622de7c3dcbe4b0f98a7048c9fb07ae9c8a1572f432db4df68b1a4803',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:45:00.000',
#   'trip_seconds': '2478',
#   'trip_miles': '20.65',
#   'pickup_community_area': '56',
#   'fare': '51.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '55.5',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]}},
#  {'trip_id': '67f674c9be25ecbadce57cb41a0b6afafb86741e',
#   'taxi_id': '698ec513d27602fcd211bb62440a555a3f23bebbe3b2a1ec9ba6466a63bab46628c6dc1622de7c3dcbe4b0f98a7048c9fb07ae9c8a1572f432db4df68b1a4803',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:45:00.000',
#   'trip_seconds': '2468',
#   'trip_miles': '20.65',
#   'pickup_community_area': '56',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]}},
#  {'trip_id': '65eb3087e514450a3fbf5739722003b12bc3a0af',
#   'taxi_id': '6898e40854937399e0ef25dad63740d21b20593439090721b2f747b039ab24c5e74ebda726b98515a4b4c6b7dd9f87717cfc7c1b52e3a8b4d52245214f09d229',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:30:00.000',
#   'trip_seconds': '1717',
#   'trip_miles': '10.95',
#   'pickup_community_area': '39',
#   'dropoff_community_area': '50',
#   'fare': '29.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '29.75',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.808916283',
#   'pickup_centroid_longitude': '-87.596183344',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5961833442, 41.8089162826]},
#   'dropoff_centroid_latitude': '41.706125752',
#   'dropoff_centroid_longitude': '-87.598255838',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5982558383, 41.7061257523]}},
#  {'trip_id': '63096a0effe5b3355a69e4347019aed9d8e9b50b',
#   'taxi_id': 'e8b30fe3cdcf458994b6943ba607e06f31b92202cab6b738f759f564007e1381a6cc1e7da2f48c2b0ced5c9dddbdf795c762884b2f0ac46f11406772d87f1ca0',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:15:00.000',
#   'trip_seconds': '364',
#   'trip_miles': '3.26',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031770700',
#   'pickup_community_area': '76',
#   'fare': '10.5',
#   'tips': '3.6',
#   'tolls': '0',
#   'extras': '7',
#   'trip_total': '21.6',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.982775009',
#   'dropoff_centroid_longitude': '-87.8773054',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.8773053996, 41.9827750091]}},
#  {'trip_id': '5deba276ba3b5144887f316f3db0848dfd953dea',
#   'taxi_id': '57f6651b7b2eb4a909751a93769dadbe2d837ed6ceaa777953e26fbd5afd06205219e28a264ec30a125cabe478d7f2319fcc5446bdc1d7bef2568ad6d866c032',
#   'trip_start_timestamp': '2025-01-11T21:00:00.000',
#   'trip_end_timestamp': '2025-01-11T21:15:00.000',
#   'trip_seconds': '525',
#   'trip_miles': '1.25',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '28',
#   'fare': '7.25',
#   'tips': '4',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '12.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  ...]
